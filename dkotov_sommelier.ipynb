# %%
# !ls

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # V.1 Exploring the green reds
# ## a) plot a scatterplot matrix

# %%
data = pd.read_csv('resources/winequality-red.csv', sep=';')

for column in data: 
    feature = data[column]
    quality = data['quality']
    plt.xlabel = feature.name
    plt.scatter(feature, quality)
    plt.show()
    

# feature = data['fixed acidity']
# quality = data['quality']

# plt.xlabel('feature')
# plt.ylabel('quality')

# plt.scatter(feature, quality)
# plt.show()
